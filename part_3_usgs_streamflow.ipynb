# %% [markdown]
# Where did the water go?

# %%
# !pip install -U dataretrieval
# Out:
# Collecting dataretrieval
#   Downloading dataretrieval-0.7-py3-none-any.whl (16 kB)
# Requirement already satisfied: pandas in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from dataretrieval) (1.4.2)
# Requirement already satisfied: requests in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from dataretrieval) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from pandas->dataretrieval) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from pandas->dataretrieval) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from pandas->dataretrieval) (1.22.3)
# Requirement already satisfied: six>=1.5 in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->dataretrieval) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from requests->dataretrieval) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from requests->dataretrieval) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from requests->dataretrieval) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/disk/p/dlhogan/miniconda3/envs/metpy/lib/python3.8/site-packages (from requests->dataretrieval) (3.3)
# Installing collected packages: dataretrieval
# Successfully installed dataretrieval-0.7

# %%
import dataretrieval.nwis as nwis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

plt.style.use('ggplot')

# %%
# specify the USGS site code for which we want data.
sites = {'Quinault River':'12039500','Elwa River':'12045500','Big Quilcene River':'12052210','Hoh River':'12041200','Queets River':'12040500','Duckabush River':'12054000'}
start_date = '2015-11-12'
end_date='2015-11-19'

df_discharge = nwis.get_record(sites=list(sites.values()), service='iv', start=start_date, end=end_date, parameterCd='00060')
df_heights = nwis.get_record(sites=list(sites.values()), service='iv', start=start_date, end=end_date, parameterCd='00065')

# # get water quality samples (qwdata)
df2 = nwis.get_stats(sites=list(sites.values())[0], statTypeCd='all')

# # get basic info about the site
df3 = nwis.get_info(sites=list(sites.values()))

# %%
# Out:
#                                           station_nm   alt_va  drain_area_va
# 0                QUINAULT RIVER AT QUINAULT LAKE, WA   178.44          264.0
# 1                   QUEETS RIVER NEAR CLEARWATER, WA    14.50          445.0
# 2         HOH RIVER AT US HIGHWAY 101 NEAR FORKS, WA   163.64          253.0
# 3   ELWHA RIVER AT MCDONALD BR NEAR PORT ANGELES, WA   200.00          269.0
# 4  BIG QUILCENE RIVER BELOW DIVERSION NR QUILCENE...  1012.62           49.4
# 5                   DUCKABUSH RIVER NEAR BRINNON, WA   241.49           66.5

# %%
df3[0][df3[0]['site_no']==v]['drain_area_va']
# Out:
# 66.5

# %%
for k,v in sites.items():
    fig, axs = plt.subplots(2, tight_layout=True, sharex=True, figsize=(10,7))
    da_mi2 = df3[0][df3[0]['site_no']==v]['drain_area_va'].values[0]
    df_discharge.loc[v]['00060'].plot(ax=axs[0], color='purple')

    axs[0].axvline(dt.datetime(2015,11,17,0), color='blue', ls='--')
    axs[0].set_xlabel('Date')
    axs[0].set_ylabel('Discharge (cfs)')
    axs[0].set_title(f'Discharge at {k}: site no. {v}\nDrainage Area = {da_mi2} mi$^2$')
    

    df_heights.loc[v]['00065'].plot(ax=axs[1], color='black')
    
    axs[1].axvline(dt.datetime(2015,11,17,0), color='blue', ls='--')
    axs[1].set_xlabel('Date')
    axs[1].set_ylabel('Gage Height (ft)')
    axs[1].set_title(f'Gage Height at {k}: site no. {v}')

# %%
for k, v in sites.items():
    rating = nwis.get_ratings(site=v)[0]
    fig, ax = plt.subplots(figsize=(5,5))
    idx = df_discharge.loc[v]['00060'].idxmax()
    rating.plot(x='INDEP',y='DEP', ax=ax)
    ax.scatter(df_heights.loc[v]['00065'].loc[idx], df_discharge.loc[v]['00060'].loc[idx], c='red',s=100, marker='*')
    ax.set_xlabel('Gage Height (ft)')
    ax.set_ylabel('Discharge (cfs)')
    ax.set_title(f'Rating curve for USGS Site No. {v}\n{k}')

# %%
df4 = nwis.get_stats(list(sites.values()), statReportType='annual',statTypeCd='max')[0]

# %%
df4
# Out:
#     agency_cd   site_no  parameter_cd   ts_id  loc_web_ds  year_nu
# 0        USGS  12039500            60  148486         NaN     1912
# 1        USGS  12039500            60  148486         NaN     1913
# 2        USGS  12039500            60  148486         NaN     1914
# 3        USGS  12039500            60  148486         NaN     1915
# 4        USGS  12039500            60  148486         NaN     1916
# ..        ...       ...           ...     ...         ...      ...
# 508      USGS  12054000            65  148566         NaN     2013
# 509      USGS  12054000            65  148566         NaN     2014
# 510      USGS  12054000            65  148566         NaN     2016
# 511      USGS  12054000            65  148566         NaN     2018
# 512      USGS  12054000            65  148566         NaN     2020
#
# [513 rows x 6 columns]
